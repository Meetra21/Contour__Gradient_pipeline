# %% [markdown]
# <a href="https://colab.research.google.com/github/Meetra21/Contour__Gradient_pipeline/blob/main/Contour__Gradient_pipeline_Digits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# If you need these in Colab, uncomment:
# !pip install --quiet tensorflow tensorflow-datasets opencv-python tqdm scikit-learn

import cv2
import time
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras import layers, models, callbacks
from sklearn.model_selection import train_test_split

# -----------------------------
# 1) Boundary + central-diff gradients (+ magnitude)
# -----------------------------
def _auto_canny_edges_uint8(img_uint8, sigma=0.33):
    v = np.median(img_uint8)
    lower = int(max(0, (1.0 - sigma) * v))
    upper = int(min(255, (1.0 + sigma) * v))
    return cv2.Canny(img_uint8, lower, upper, L2gradient=True)

def compute_boundary_gradients(images, use_canny=True, add_mag=True):
    """
    images: (N, 28, 28) uint8 or float
    Returns: (N, C, 28, 28) float32 where C=2 (gx,gy) or 3 (gx,gy,mag)
    - central-difference grads (vectorized)
    - masked to edges (Canny) to emphasize contours
    - per-image L2 normalization to stabilize scale
    """
    imgs = images.astype(np.float32)
    if imgs.max() > 1.0:
        imgs /= 255.0

    N, H, W = imgs.shape
    p = np.pad(imgs, ((0,0),(1,1),(1,1)), mode='edge')

    gx = (p[:, 1:-1, 2:] - p[:, 1:-1, :-2]) * 0.5
    gy = (p[:, 2:, 1:-1] - p[:, :-2, 1:-1]) * 0.5

    if use_canny:
        edges = np.empty_like(images, dtype=np.uint8)
        imgs_u8 = (imgs * 255.0 + 0.5).astype(np.uint8)
        for i in range(N):
            edges[i] = _auto_canny_edges_uint8(imgs_u8[i])
        mask = (edges > 0).astype(np.float32)
    else:
        # fallback boundary proxy (morph gradient)
        kernel = np.ones((3,3), np.uint8)
        imgs_u8 = (imgs * 255.0 + 0.5).astype(np.uint8)
        dil = np.stack([cv2.dilate(im, kernel, iterations=1) for im in imgs_u8], axis=0)
        ero = np.stack([cv2.erode(im, kernel, iterations=1) for im in imgs_u8], axis=0)
        mask = ((dil - ero) > 0).astype(np.float32)

    gx *= mask
    gy *= mask

    eps = 1e-6
    norm = np.sqrt((gx**2 + gy**2).sum(axis=(1,2), keepdims=True)) + eps
    gx /= norm
    gy /= norm

    if add_mag:
        mag = np.sqrt(gx**2 + gy**2)
        feats = np.stack([gx, gy, mag], axis=1).astype(np.float32)  # (N,3,H,W)
    else:
        feats = np.stack([gx, gy], axis=1).astype(np.float32)       # (N,2,H,W)

    return feats

# -----------------------------
# 2) Load MNIST via TFDS
# -----------------------------
(ds_train, ds_test), ds_info = tfds.load(
    'mnist',
    split=['train', 'test'],
    as_supervised=True,
    with_info=True
)

# -----------------------------
# 3) Convert to NumPy arrays
# -----------------------------
all_images, all_labels = [], []
for img, lbl in tfds.as_numpy(ds_train.concatenate(ds_test)):
    all_images.append(img.squeeze())   # (28,28) uint8
    all_labels.append(int(lbl))        # 0..9
all_images = np.stack(all_images)      # (70000,28,28)
all_labels = np.array(all_labels, dtype=np.int32)

# -----------------------------
# 4) Stratified 80/20 split
# -----------------------------
X_train, X_test, y_train, y_test = train_test_split(
    all_images, all_labels,
    train_size=0.8,
    stratify=all_labels,
    random_state=42
)

# -----------------------------
# 5) Boundary+central-diff grads (+mag)
# -----------------------------
grad_train = compute_boundary_gradients(X_train, use_canny=True, add_mag=True)  # (N,3,28,28)
grad_test  = compute_boundary_gradients(X_test,  use_canny=True, add_mag=True)

# -----------------------------
# 6) Flatten + global z-score standardization
# -----------------------------
C = grad_train.shape[1]
X_train_feat = grad_train.reshape(-1, C*28*28)
X_test_feat  = grad_test.reshape(-1,  C*28*28)

mean = X_train_feat.mean(axis=0, keepdims=True)
std  = X_train_feat.std(axis=0, keepdims=True) + 1e-6
X_train_feat = (X_train_feat - mean) / std
X_test_feat  = (X_test_feat  - mean) / std

# -----------------------------
# 7) MLP model (accuracy-leaning but fast)
# -----------------------------
model = models.Sequential([
    layers.Input(shape=(C*28*28,)),
    layers.Dense(1024), layers.BatchNormalization(), layers.LeakyReLU(alpha=0.01),
    layers.Dropout(0.4),

    layers.Dense(512), layers.BatchNormalization(), layers.LeakyReLU(alpha=0.01),
    layers.Dropout(0.3),

    layers.Dense(256), layers.BatchNormalization(), layers.LeakyReLU(alpha=0.01),
    layers.Dropout(0.2),

    layers.Dense(10, activation='softmax')
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# -----------------------------
# 8) Callbacks
# -----------------------------
es = callbacks.EarlyStopping(
    monitor='val_accuracy', patience=6,
    restore_best_weights=True, verbose=1
)
rlr = callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5,
    patience=3, min_lr=1e-6, verbose=1
)

# -----------------------------
# 9) Train
# -----------------------------
t0 = time.time()
history = model.fit(
    X_train_feat, y_train,
    validation_split=0.1,
    epochs=60,
    batch_size=256,                 # larger batch; features are small
    callbacks=[es, rlr],
    verbose=2
)
train_time = time.time() - t0

# -----------------------------
# 10) Evaluate
# -----------------------------
t1 = time.time()
test_loss, test_acc = model.evaluate(X_test_feat, y_test, verbose=0)
infer_time = time.time() - t1

# -----------------------------
# 11) Report
# -----------------------------
print(f"\nMNIST Boundary-Masked Central-Gradient (+Mag) MLP")
print(f"Input Channels  : {C}")
print(f"Test Accuracy   : {test_acc*100:.2f}%")
print(f"Training Time   : {train_time:.1f}s")
print(f"Inference Time  : {infer_time:.3f}s for {X_test_feat.shape[0]} samples")
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/mnist/3.0.1 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/mnist/3.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/mnist/incomplete.D0VST7_3.0.1/mnist-train.tfrecord*...:   0%|          | 0…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/mnist/incomplete.D0VST7_3.0.1/mnist-test.tfrecord*...:   0%|          | 0/…
# Dataset mnist downloaded and prepared to /root/tensorflow_datasets/mnist/3.0.1. Subsequent calls will reuse this data.
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/60
# 197/197 - 24s - 122ms/step - accuracy: 0.8673 - loss: 0.4280 - val_accuracy: 0.9393 - val_loss: 0.1930 - learning_rate: 1.0000e-03
# Epoch 2/60
# 197/197 - 19s - 95ms/step - accuracy: 0.9483 - loss: 0.1662 - val_accuracy: 0.9552 - val_loss: 0.1504 - learning_rate: 1.0000e-03
# Epoch 3/60
# 197/197 - 21s - 108ms/step - accuracy: 0.9646 - loss: 0.1109 - val_accuracy: 0.9571 - val_loss: 0.1460 - learning_rate: 1.0000e-03
# Epoch 4/60
# 197/197 - 19s - 99ms/step - accuracy: 0.9740 - loss: 0.0801 - val_accuracy: 0.9602 - val_loss: 0.1401 - learning_rate: 1.0000e-03
# Epoch 5/60
# 197/197 - 20s - 101ms/step - accuracy: 0.9803 - loss: 0.0618 - val_accuracy: 0.9616 - val_loss: 0.1449 - learning_rate: 1.0000e-03
# Epoch 6/60
# 197/197 - 21s - 108ms/step - accuracy: 0.9842 - loss: 0.0492 - val_accuracy: 0.9650 - val_loss: 0.1347 - learning_rate: 1.0000e-03
# Epoch 7/60
# 197/197 - 20s - 99ms/step - accuracy: 0.9863 - loss: 0.0435 - val_accuracy: 0.9636 - val_loss: 0.1489 - learning_rate: 1.0000e-03
# Epoch 8/60
# 197/197 - 21s - 106ms/step - accuracy: 0.9878 - loss: 0.0366 - val_accuracy: 0.9661 - val_loss: 0.1449 - learning_rate: 1.0000e-03
# Epoch 9/60
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 197/197 - 20s - 100ms/step - accuracy: 0.9899 - loss: 0.0308 - val_accuracy: 0.9675 - val_loss: 0.1372 - learning_rate: 1.0000e-03
# Epoch 10/60
# 197/197 - 20s - 104ms/step - accuracy: 0.9932 - loss: 0.0215 - val_accuracy: 0.9698 - val_loss: 0.1197 - learning_rate: 5.0000e-04
# Epoch 11/60
# 197/197 - 21s - 107ms/step - accuracy: 0.9959 - loss: 0.0135 - val_accuracy: 0.9695 - val_loss: 0.1237 - learning_rate: 5.0000e-04
# Epoch 12/60
# 197/197 - 20s - 100ms/step - accuracy: 0.9971 - loss: 0.0095 - val_accuracy: 0.9700 - val_loss: 0.1253 - learning_rate: 5.0000e-04
# Epoch 13/60
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 197/197 - 20s - 101ms/step - accuracy: 0.9974 - loss: 0.0094 - val_accuracy: 0.9705 - val_loss: 0.1303 - learning_rate: 5.0000e-04
# Epoch 14/60
# 197/197 - 19s - 95ms/step - accuracy: 0.9975 - loss: 0.0077 - val_accuracy: 0.9718 - val_loss: 0.1269 - learning_rate: 2.5000e-04
# Epoch 15/60
# 197/197 - 20s - 104ms/step - accuracy: 0.9983 - loss: 0.0064 - val_accuracy: 0.9720 - val_loss: 0.1253 - learning_rate: 2.5000e-04
# Epoch 16/60
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 197/197 - 21s - 106ms/step - accuracy: 0.9983 - loss: 0.0058 - val_accuracy: 0.9707 - val_loss: 0.1293 - learning_rate: 2.5000e-04
# Epoch 17/60
# 197/197 - 40s - 201ms/step - accuracy: 0.9989 - loss: 0.0045 - val_accuracy: 0.9716 - val_loss: 0.1299 - learning_rate: 1.2500e-04
# Epoch 18/60
# 197/197 - 19s - 96ms/step - accuracy: 0.9990 - loss: 0.0044 - val_accuracy: 0.9712 - val_loss: 0.1279 - learning_rate: 1.2500e-04
# Epoch 19/60
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 197/197 - 21s - 108ms/step - accuracy: 0.9989 - loss: 0.0042 - val_accuracy: 0.9714 - val_loss: 0.1286 - learning_rate: 1.2500e-04
# Epoch 20/60
# 197/197 - 20s - 102ms/step - accuracy: 0.9992 - loss: 0.0035 - val_accuracy: 0.9720 - val_loss: 0.1287 - learning_rate: 6.2500e-05
# Epoch 21/60
# 197/197 - 21s - 106ms/step - accuracy: 0.9992 - loss: 0.0030 - val_accuracy: 0.9714 - val_loss: 0.1285 - learning_rate: 6.2500e-05
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 15.
#
# MNIST Boundary-Masked Central-Gradient (+Mag) MLP
# Input Channels  : 3
# Test Accuracy   : 97.25%
# Training Time   : 447.3s
# Inference Time  : 3.978s for 14000 samples
